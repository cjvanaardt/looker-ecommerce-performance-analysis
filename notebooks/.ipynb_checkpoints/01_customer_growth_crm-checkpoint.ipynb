# %% [markdown]
# # Customer Growth and CRM
#
# This notebook covers analysis for answering questions related to the Customer Growth and CRM team.
# 1. How have repeat purchase patterns changed over the last 24–36 months, segmented by acquisition channel, demographics (age/gender), and location?
# 2. Which customer behaviours and characteristics best predict long-term value (e.g. first-purchase category, time to second order), where long-term value is defined by revenue and profit?
# 3. Which customer groups consistently drive disproportionate revenue?
# 4. Where do post-purchase drop-offs occur (e.g. returns, low engagement), and how do these vary by segment?

# %% [markdown]
# ## Data loading and preparation
#
# Load data and prepare tables to be used for analysis.

# %%
# load modules
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load data
dist_ctrs = pd.read_parquet("../data/clean/distribution_centers.parquet")
events = pd.read_parquet("../data/clean/events.parquet")
inv_items = pd.read_parquet("../data/clean/inventory_items.parquet")
order_items = pd.read_parquet("../data/clean/order_items.parquet")
orders = pd.read_parquet("../data/clean/orders.parquet")
products = pd.read_parquet("../data/clean/products.parquet")
users = pd.read_parquet("../data/clean/users.parquet")

# %% [markdown]
# ### Customer ABT

# %%
# static and direct features
customer_abt = users.copy()

customer_abt = customer_abt.rename(columns={'traffic_source': 'acquisition_channel'})

# determine analysis date: end of last month with transactions
last_date = max(
    orders['created_at'].max(),
    order_items['created_at'].max(),
    ) - pd.offsets.MonthEnd(0)

customer_abt['analysis_date'] = last_date.normalize()

# define the age_bin
customer_abt['age_bin'] = pd.cut(
    customer_abt['age'],
    bins=range(10, 81, 10),
    right=False
)

customer_abt = customer_abt[['user_id', 'analysis_date', 'age_bin', 'gender', 'country', 'acquisition_channel']].copy()

# first purchase features

# start with all orders
customer_order_items = orders.merge(order_items, on='order_id').merge(products[['product_id', 'category', 'cost']], on='product_id')
customer_order_items = customer_order_items.rename(columns={
    'user_id_x': 'user_id',
    'created_at_x': 'order_date',
    'created_at_y': 'order_item_date'
})

# calculate profit
customer_order_items['profit'] = customer_order_items['sale_price'] - customer_order_items['cost']

# identify first order date per user
first_order_date = customer_order_items.groupby('user_id')['order_date'].min().reset_index(name='first_purchase_date')

# identify first order rows from first order date
first_order_rows = customer_order_items.merge(first_order_date.rename(columns={'first_purchase_date': 'order_date'}), on=['user_id', 'order_date'])

# calcualte first order aggregates
first_order_features = first_order_rows.groupby('user_id').agg(
    first_purchase_date=('order_date', 'first'),
    first_order_revenue=('sale_price', 'sum'),
    first_order_profit=('profit', 'sum'),
    first_order_item_count=('order_item_id', 'nunique')
).reset_index()

# calculate first purchase category
first_order_category = first_order_rows.groupby(['user_id', 'category']).agg(
    number_of_category_items=('num_of_item', 'sum'),
    category_profit=('profit', 'sum')
).reset_index()
first_order_category = first_order_category.sort_values(by=['user_id', 'number_of_category_items', 'category_profit'], ascending=[True, False, False])
first_order_category = first_order_category.groupby(['user_id']).head(1)[['user_id', 'category']].rename(columns={'category': 'first_purchase_category'})

# combine and add cohort month
first_order_features = first_order_features.merge(first_order_category, on='user_id', how='left')
first_order_features['acquisition_month'] = first_order_features['first_purchase_date'].dt.to_period('M').dt.to_timestamp()

# merge with customer_abt
customer_abt = customer_abt.merge(first_order_features, on='user_id')


# calculate date differece features

# calculate previous order dates
customer_orders = orders.sort_values(['user_id', 'created_at'])
customer_orders['prev_order_date'] = customer_orders.groupby('user_id')['created_at'].shift(1)

# average days between orders
customer_orders['days_between_orders'] = (customer_orders['created_at'] - customer_orders['prev_order_date']).dt.days
avg_days_between_orders = customer_orders.groupby('user_id')['days_between_orders'].mean().reset_index(name='avg_days_between_orders')

# days since first purchase
customer_abt['days_since_first_purchase'] = (customer_abt['analysis_date'] - customer_abt['first_purchase_date']).dt.days

# time to second order
customer_orders['order_number'] = customer_orders.groupby('user_id')['created_at'].rank(method='dense').astype(int)
second_orders = customer_orders[customer_orders['order_number'] == 2].groupby('user_id').agg(second_order_date=('created_at', 'min')).reset_index()

# merge with customer_abt
customer_abt = customer_abt.merge(second_orders, on='user_id', how='left')
customer_abt = customer_abt.merge(avg_days_between_orders, on='user_id', how='left')
customer_abt['time_to_second_order'] = (customer_abt['second_order_date'] - customer_abt['first_purchase_date']).dt.days


# calculate horizon attributes

# add first_purchase date onto order_items
customer_order_items_fp = customer_order_items.merge(customer_abt[['user_id', 'first_purchase_date']], on='user_id')

# determine days since first order
customer_order_items_fp['days_since_first'] = (customer_order_items_fp['order_date'] - customer_order_items_fp['first_purchase_date']).dt.days

# specify desired horizons
horizons = [30, 90, 180, 365, 540]

for h in horizons:
    mask = (customer_order_items_fp['days_since_first'] <= h) & (customer_order_items_fp['days_since_first'] >= 0)
    horizon_orders = customer_order_items_fp[mask].groupby('user_id').agg(
        **{f'orders_{h}d':('order_id', 'nunique'),
          f'revenue_{h}d':('sale_price', 'sum'),
          f'profit_{h}d':('profit', 'sum')}
    ).reset_index()
    
    customer_abt = customer_abt.merge(horizon_orders, on='user_id')
    
    customer_abt[f'has_repeat_{h}d'] = (customer_abt[f'orders_{h}d'] >= 2).astype(int)


# calculate lifetime value

lifetime_features = customer_order_items.groupby('user_id').agg(
    total_orders=('order_id', 'nunique'),
    total_items=('order_item_id', 'nunique'),
    lifetime_revenue=('sale_price', 'sum'),
    lifetime_profit=('profit', 'sum'),
    last_order_date=('order_date', 'last') 
).reset_index()

customer_abt = customer_abt.merge(lifetime_features, on='user_id')
customer_abt['lifetime_AOV'] = customer_abt['lifetime_revenue'] / customer_abt['total_orders']
customer_abt['days_since_last_order'] = (customer_abt['analysis_date'] - customer_abt['last_order_date']).dt.days


# churn, returns, and engagement

# churn
for h in horizons:
    customer_abt[f'churned_{h}d'] = (customer_abt['days_since_last_order'] > h).astype(int)

# returns
cancelled_order_items = customer_order_items[customer_order_items['status_y'] == 'Returned']
returned = cancelled_order_items.groupby('user_id').agg(
    items_returned=('order_item_id', 'nunique'),
    orders_returned=('order_id', 'nunique')
).reset_index()

customer_abt = customer_abt.merge(returned, on='user_id', how='left')

customer_abt['order_return_rate'] = customer_abt['orders_returned'] / customer_abt['total_orders']
customer_abt['item_return_rate'] = customer_abt['items_returned'] / customer_abt['total_items']
customer_abt['ever_returned'] = (customer_abt['items_returned'] > 0)


# engagement

# identify last event
events = events.sort_values(by=['user_id', 'created_at', 'sequence_number'], ascending=[True, False, False])
last_events = events.groupby('user_id').head(1)
last_events = last_events.rename(columns={'created_at':'last_event_date', 'browser':'last_browser', 'uri':'last_uri', 'event_type':'last_event_type'})
last_events = last_events[['user_id', 'last_event_date', 'last_browser', 'last_uri', 'last_event_type']]

customer_abt = customer_abt.merge(last_events, on='user_id')
customer_abt['days_since_last_event'] = (customer_abt['analysis_date'] - customer_abt['last_event_date']).dt.days

# no activity and matured flags
for h in horizons:
    customer_abt[f'no_activity_{h}d'] = (customer_abt['days_since_last_event'] > h).astype(int)
    customer_abt[f'mature_{h}d'] = (customer_abt['analysis_date'] - customer_abt['first_purchase_date']).dt.days > h


customer_abt
# Out:
#        user_id analysis_date   age_bin gender country acquisition_channel  \
# 0          457    2024-01-31  [60, 70)      M  Brasil              Search
# 1        36280    2024-01-31  [10, 20)      M  Brasil               Email
# 2        60193    2024-01-31  [60, 70)      M  Brasil              Search
# 3        64231    2024-01-31  [20, 30)      F  Brasil              Search
# 4        72187    2024-01-31  [40, 50)      F  Brasil              Search
# ...        ...           ...       ...    ...     ...                 ...
# 80039    93247    2024-01-31  [30, 40)      F  France              Search
# 80040    59110    2024-01-31  [10, 20)      M  France             Organic
# 80041    57045    2024-01-31  [50, 60)      F  France              Search
# 80042    73312    2024-01-31  [10, 20)      F  France              Search
# 80043    77764    2024-01-31  [60, 70)      F  France              Search
#
#       first_purchase_date  first_order_revenue  first_order_profit  \
# 0     2023-10-08 13:51:00                99.99               60.29
# 1     2020-05-04 06:10:00                29.97               17.80
# 2     2021-03-21 11:26:00                24.00                8.69
# 3     2020-03-27 06:45:00                49.98               28.54
# 4     2023-10-05 14:53:00                21.00               10.69
# ...                   ...                  ...                 ...
# 80039 2022-03-25 01:36:00                49.00               27.15
# 80040 2023-04-24 12:01:00               198.80              101.17
# 80041 2021-09-23 11:39:00                69.00               40.46
# 80042 2023-08-09 16:24:00                78.50               38.32
# 80043 2023-03-13 05:57:00                 9.00                4.49
#
#        first_order_item_count  ... no_activity_30d mature_30d  \
# 0                           1  ...               1       True
# 1                           1  ...               1       True
# 2                           1  ...               1       True
# 3                           1  ...               1       True
# 4                           1  ...               1       True
# ...                       ...  ...             ...        ...
# 80039                       1  ...               1       True
# 80040                       4  ...               1       True
# 80041                       2  ...               1       True
# 80042                       2  ...               1       True
# 80043                       1  ...               1       True
#
#        no_activity_90d mature_90d  no_activity_180d  mature_180d  \
# 0                    1       True                 0        False
# 1                    1       True                 1         True
# 2                    1       True                 1         True
# 3                    1       True                 1         True
# 4                    1       True                 0        False
# ...                ...        ...               ...          ...
# 80039                1       True                 1         True
# 80040                1       True                 0         True
# 80041                1       True                 1         True
# 80042                1       True                 0        False
# 80043                1       True                 0         True
#
#        no_activity_365d  mature_365d  no_activity_540d  mature_540d
# 0                     0        False                 0        False
# 1                     1         True                 1         True
# 2                     1         True                 1         True
# 3                     0         True                 0         True
# 4                     0        False                 0        False
# ...                 ...          ...               ...          ...
# 80039                 1         True                 0         True
# 80040                 0        False                 0        False
# 80041                 1         True                 1         True
# 80042                 0        False                 0        False
# 80043                 0        False                 0        False
#
# [80044 rows x 68 columns]

# %% [markdown]
# ### cohort table

# %%
cohort_averages[['avg_time_to_second_order', '

# %%
cohort_averages = customer_abt.groupby(
    ['acquisition_month', 'age_bin', 'gender', 'country', 'acquisition_channel'],
    observed=True
).agg(
    cohort_size                  = ('user_id', 'nunique'),
    
    # early behaviour
    avg_time_to_second_order     = ('time_to_second_order', 'mean'),           
    median_time_to_second_order  = ('time_to_second_order', 'median'),         
    avg_days_between_orders      = ('avg_days_between_orders', 'mean'),        

    # value & lifetime signals
    avg_lifetime_AOV             = ('lifetime_AOV', 'mean'),                   
    avg_lifetime_profit          = ('lifetime_profit', 'mean'),                
    avg_total_items              = ('total_items', 'mean'),                    

    # median values for skewed metrics
    median_lifetime_AOV=('lifetime_AOV', 'median'),
    median_lifetime_profit=('lifetime_profit', 'median'),
    median_days_since_last_order=('days_since_last_order', 'median'),
    
    # recency & activity
    avg_days_since_last_order    = ('days_since_last_order', 'mean'),         
    
    # share of mature customers
    share_mature_30d             = ('mature_30d', 'mean'),
    share_mature_90d             = ('mature_90d', 'mean'),
    share_mature_180d            = ('mature_180d', 'mean'),
    share_mature_365d            = ('mature_365d', 'mean'),
    share_mature_540d            = ('mature_540d', 'mean'),

    # cohort behaviour
    repeat_rate_30d              = ('has_repeat_30d', 'mean'),
    repeat_rate_90d              = ('has_repeat_90d', 'mean'),
    repeat_rate_180d             = ('has_repeat_180d', 'mean'),
    repeat_rate_365d             = ('has_repeat_365d', 'mean'),
    repeat_rate_540d             = ('has_repeat_540d', 'mean'),
    avg_revenue_30d              = ('revenue_30d', 'mean'),
    avg_revenue_90d              = ('revenue_90d', 'mean'),
    avg_revenue_180d             = ('revenue_180d', 'mean'),
    avg_revenue_365d             = ('revenue_365d', 'mean'),
    avg_revenue_540d             = ('revenue_540d', 'mean'),
    avg_profit_30d              = ('profit_30d', 'mean'),
    avg_profit_90d              = ('profit_90d', 'mean'),
    avg_profit_180d             = ('profit_180d', 'mean'),
    avg_profit_365d             = ('profit_365d', 'mean'),
    avg_profit_540d             = ('profit_540d', 'mean'),
    avg_orders_30d              = ('orders_30d', 'mean'),
    avg_orders_90d              = ('orders_90d', 'mean'),
    avg_orders_180d             = ('orders_180d', 'mean'),
    avg_orders_365d             = ('orders_365d', 'mean'),
    avg_orders_540d             = ('orders_540d', 'mean'),
).reset_index()

# %%
# Repeaters-only averages (customers with ≥2 orders lifetime, or you can use has_repeat_365d == 1)
repeaters_only = customer_abt[customer_abt['total_orders'] >= 2]

repeaters_averages = repeaters_only.groupby(
    ['acquisition_month', 'age_bin', 'gender', 'country', 'acquisition_channel'],
    observed=True
).agg(
    repeaters_size                  = ('user_id', 'nunique'),
    
    avg_revenue_180d_repeaters      = ('revenue_180d', 'mean'),
    avg_profit_180d_repeaters       = ('profit_180d', 'mean'),
    avg_revenue_365d_repeaters      = ('revenue_365d', 'mean'),
    avg_profit_365d_repeaters       = ('profit_365d', 'mean'),
    
    avg_lifetime_AOV_repeaters      = ('lifetime_AOV', 'mean'),
    avg_lifetime_profit_repeaters   = ('lifetime_profit', 'mean'),
    avg_total_items_repeaters       = ('total_items', 'mean'),
    
    # early signals among repeaters
    avg_time_to_second_repeaters    = ('time_to_second_order', 'mean'),
    avg_days_between_repeaters      = ('avg_days_between_orders', 'mean'),
).reset_index()

# Merge back to main cohort_averages (left join)
cohort_averages = cohort_averages.merge(
    repeaters_averages,
    on=['acquisition_month', 'age_bin', 'gender', 'country', 'acquisition_channel'],
    how='left'
)

# Optional: calculate % of cohort that are repeaters (sanity check)
cohort_averages['repeaters_share'] = cohort_averages['repeaters_size'] / cohort_averages['cohort_size']

# %%
cohort_averages[['repeaters_share', 'repeat_rate_180d', 'repeat_rate_365d']].describe()
# Out:
#        repeaters_share  repeat_rate_180d  repeat_rate_365d
# count     11708.000000      17996.000000      17996.000000
# mean          0.637294          0.172921          0.264971
# std           0.301366          0.288252          0.339678
# min           0.055556          0.000000          0.000000
# 25%           0.375000          0.000000          0.000000
# 50%           0.500000          0.000000          0.100000
# 75%           1.000000          0.250000          0.500000
# max           1.000000          1.000000          1.000000

# %% [markdown]
# ### Sanity Checks and Data Quality

# %%
# main analysis with 365 and 180 day cohorts
# keep only mature cohorts

df = cohort_averages[cohort_averages['share_mature_365d'] >= 0.6].copy()

df['cohort_display'] = df['acquisition_month'].dt.strftime('%Y-%m')

# %% [markdown]
# General Trends

# %%
trend_overall = df.groupby('acquisition_month').agg(
    repeat_rate_180d_mean=('repeat_rate_180d', 'mean'),
    repeat_rate_365d_mean=('repeat_rate_365d', 'mean'),
    time_to_second_mean=('avg_time_to_second_order', 'mean'),
    time_to_second_median=('avg_time_to_second_order', 'median'),
    revenue_180d_mean=('avg_revenue_180d', 'mean'),
    profit_180d_mean=('avg_profit_180d', 'mean'),
    orders_180d_mean=('avg_orders_180d', 'mean')
).reset_index()

fig = px.line(
    trend_overall,
    x='acquisition_month',
    y=['repeat_rate_180d_mean', 'repeat_rate_365d_mean'],
    title='Repeat Rates by Cohort Month (Overall)'
)
fig.show()

# %%
fig = px.line(
    trend_overall,
    x='acquisition_month',
    y=['time_to_second_mean', 'time_to_second_median'],
    title='Time to Second Order (Days) by Cohort Month (Overall)'
)
fig.show()

# %%
fig = px.line(
    trend_overall,
    x='acquisition_month',
    y=['revenue_180d_mean', 'profit_180d_mean'],
    title='Average Revenue and Profit by Cohort Month (Overall)'
)
fig.show()

# %%
fig = px.line(
    trend_overall,
    x='acquisition_month',
    y=['orders_180d_mean'],
    title='Average Orders within 180 Days by Cohort Month (Overall)'
)
fig.show()
